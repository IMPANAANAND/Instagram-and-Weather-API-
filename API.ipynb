# %%
pip install requests

# %%
import requests

# Replace 'YOUR_API_KEY' with your actual OpenWeather API key
API_KEY = ''
BASE_URL = 'http://api.openweathermap.org/data/2.5/weather'

def get_weather(city_name):
    params = {
        'q': city_name,
        'appid': API_KEY,
        'units': 'metric'  # For Celsius; use 'imperial' for Fahrenheit
    }

    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        data = response.json()
        main = data['main']
        weather = data['weather'][0]

        temperature = main['temp']
        weather_description = weather['description']

        print(f"Temperature in {city_name}: {temperature}°C")
        print(f"Weather description: {weather_description.capitalize()}")
    else:
        print("City not found or API request failed")

# Example usage
city = input("Enter city name: ")
get_weather(city)
# Out:
# Enter city name: mysore
# Temperature in mysore: 26°C
# Weather description: Scattered clouds

# %%
import requests

# Replace 'YOUR_API_KEY' with your actual OpenWeather API key
API_KEY = ''
BASE_URL = 'http://api.openweathermap.org/data/2.5/weather'

def get_weather(city_name):
    params = {
        'q': city_name,
        'appid': API_KEY,
        'units': 'metric'  # For Celsius; use 'imperial' for Fahrenheit
    }

    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        data = response.json()
        main = data['main']
        weather = data['weather'][0]
        wind = data['wind']
        sys = data['sys']

        temperature = main['temp']
        humidity = main['humidity']
        pressure = main['pressure']
        weather_description = weather['description']
        wind_speed = wind['speed']
        visibility = data.get('visibility', 'N/A')
        cloudiness = data['clouds']['all']
        sunrise = sys['sunrise']
        sunset = sys['sunset']

        print(f"Temperature in {city_name}: {temperature}°C")
        print(f"Weather description: {weather_description.capitalize()}")
        print(f"Humidity: {humidity}%")
        print(f"Pressure: {pressure} hPa")
        print(f"Wind speed: {wind_speed} m/s")
        print(f"Visibility: {visibility} meters")
        print(f"Cloudiness: {cloudiness}%")
        print(f"Sunrise: {sunrise}")
        print(f"Sunset: {sunset}")
    else:
        print("City not found or API request failed")

# Example usage
city = input("Enter city name: ")
get_weather(city)
# Out:
# Enter city name: mysore
# Temperature in mysore: 26°C
# Weather description: Scattered clouds
# Humidity: 73%
# Pressure: 1007 hPa
# Wind speed: 6.17 m/s
# Visibility: 6000 meters
# Cloudiness: 40%
# Sunrise: 1721781485
# Sunset: 1721827285

# %%
import requests

# Define the URL
url = "https://enam.gov.in/web/Ajax_ctrl/trade_data_list"

try:
    # Make a GET request to fetch the data
    response = requests.get(url)
    response.raise_for_status()  # Will raise an HTTPError for bad responses (4xx and 5xx)

    # Check if the response content is empty or HTML
    if 'html' in response.headers.get('Content-Type', ''):
        print("Received HTML content. Response content:")
        print(response.text)  # Print the HTML content for inspection
    else:
        # Try parsing the JSON data
        try:
            data = response.json()
            # Print the data to check its structure
            print(json.dumps(data, indent=4))
        except json.JSONDecodeError:
            print("Response is not in JSON format. Content received:")
            print(response.text)

except requests.exceptions.HTTPError as http_err:
    print(f"HTTP error occurred: {http_err}")
except Exception as err:
    print(f"Other error occurred: {err}")
# Out:
# Received HTML content. Response content:
# {"status":500}

# %%
pip install httpx
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# ...

# %%
# !pip install requests

# %%
import requests
from urllib.parse import urlencode

# Define the URL
url = "https://enam.gov.in/web/Ajax_ctrl/trade_data_list"

# Prepare form data
form_data = {
    "language": "en",
    "stateName": "-- All --",
    "apmcName": "-- Select APMCs --",
    "commodityName": "-- Select Commodity --",
    "fromDate": "2024-07-23",
    "toDate": "2024-07-23"
}
form_data_encoded = urlencode(form_data)

# Make the POST request
response = requests.post(
    url,
    headers={'Content-Type': 'application/x-www-form-urlencoded'},
    data=form_data_encoded
)

# Print the response text
print(response.text)
# Out:
# {"data":[{"id":"26487487","state":"ODISHA","apmc":"SAKHIGOPAL","commodity":"COCONUT","min_price":"6","modal_price":"6","max_price":"14","commodity_arrivals":"132934","commodity_traded":"132934","created_at":"2024-07-23","status":"1","Commodity_Uom":"Nos"},{"id":"26485657","state":"MAHARASHTRA","apmc":"AATPADI","commodity":"POMEGRANATE - BHAGAWA","min_price":"15","modal_price":"45","max_price":"118","commodity_arrivals":"39140","commodity_traded":"54740","created_at":"2024-07-23","status":"1","Commodity_Uom":"Kg"},{"id":"26480554","state":"ANDHRA PRADESH","apmc":"ANANTHAPURAMU","commodity":"MOUSAMBI","min_price":"300","modal_price":"1400","max_price":"2300","commodity_arrivals":"13807","commodity_traded":"12555","created_at":"2024-07-23","status":"1","Commodity_Uom":"Qui"},{"id":"26480726","state":"ANDHRA PRADESH","apmc":"MADANAPALLE","commodity":"TOMATO","min_price":"4000","modal_price":"4000","max_price":"5600","commodity_arrivals":"10353","commodity_traded":"10980","created_at":"20
# ...

# %%
# !pip install instaloader

# %%
import instaloader

# Create an Instaloader object
L = instaloader.Instaloader()

# Define the Instagram profile you want to scrape
profile = instaloader.Profile.from_username(L.context, 'vishalpandey_21')  # Replace with the actual username

# Print profile information
print("Username:", profile.username)
print("Full Name:", profile.full_name)
print("Bio:", profile.biography)
print("Followers:", profile.followers)
print("Following:", profile.followees)
print("Posts:", profile.mediacount)
# Out:
# Username: vishalpandey_21
# Full Name: Vishal Pandey🇮🇳
# Bio: Currently in #BBOTT3 🔐🏡
# PR @greenlitnetworks
# Fashion | Lifestyle | Comedy | Dance
# For collaborations-DM or Email
# Snapchat: vishal57 || Join me on X👇
# Followers: 9841757
# Following: 568
# Posts: 3102

# %%
import instaloader

# Create an Instaloader object
L = instaloader.Instaloader()

# Define the Instagram profile you want to scrape
profile_username = 'vishalpandey_21'  # Replace with the actual username

# Load the profile
profile = instaloader.Profile.from_username(L.context, profile_username)

# Print basic profile information
print(f"Profile: {profile.username}")
print(f"Full Name: {profile.full_name}")

# Loop through each post and get likes and comments
for post in profile.get_posts():
    print(f"Post URL: {post.url}")
    print(f"Caption: {post.caption}")
    print(f"Likes: {post.likes}")
    print(f"Comments: {post.comments}")
    print("="*40)
# Out:
# Profile: vishalpandey_21
# Full Name: Vishal Pandey🇮🇳
# Post URL: https://scontent-ord5-1.cdninstagram.com/v/t51.29350-15/451416855_8675317879149019_2575196358153309620_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-ord5-1.cdninstagram.com&_nc_cat=1&_nc_ohc=cro2CbQ7tmgQ7kNvgEpQokZ&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AYDRI0biE8jBNcR0siRoX8bB7gW6FdzxBsIw4ZQ2viEbUw&oe=66A6BD78&_nc_sid=8b3546
# Caption: Khabar ho toh aisi.. 📲🔥🤙🏻 #NayaBaharwala 👀🕵🏻‍♂️
#
# Styled by @nowmee_chowdary
# Wearing @ostilos.official
#
# @officialjiocinema
# …
#
# #VishalPandey #Vishalians #BiggBossOTT3 #BBOTT3 #BiggBossOTT
# Likes: 401593
# Comments: 1579
# ...
# Post URL: https://scontent-ord5-1.cdninstagram.com/v/t51.29350-15/450803130_1947046355747984_8940259738816688508_n.jpg?stp=dst-jpg_e15&_nc_ht=scontent-ord5-1.cdninstagram.com&_nc_cat=108&_nc_ohc=RMYNPx5KsfMQ7kNvgHdjJqo&edm=AOQ1c0wBAAAA&ccb=7-5&oh=00_AYAbtBpVynOkcVmC8rn7enBsXwaUb6Sxuv6njX6R6rYOBw&oe=66A6C371&_nc_sid=8b3546
# ...
